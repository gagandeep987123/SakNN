# %%
import tSNE_performance 
import numpy as np

# %%
with open('../tSNE_transform/transformationData/random_2d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)

# %%
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 997
# 994
# 992
#
#
# k in higher dimension: 300
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 998
# 995
# 994
#
#
# k in higher dimension: 400
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 999
# 998
# 998
#
#
# k in higher dimension: 500
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 999
# 999
#
#
# k in higher dimension: 750
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 2000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 250
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 0.9999 	oar :  1.0
# 40 : 0.9996 	oar :  1.0
# 50 : 0.99924 	oar :  1.0
#
#
# k in higher dimension: 300
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 0.9999333333333333 	oar :  1.0
# 40 : 0.9997 	oar :  1.0
# 50 : 0.99942 	oar :  1.0
#
#
# k in higher dimension: 400
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 0.9999666666666667 	oar :  1.0
# 40 : 0.99985 	oar :  1.0
# 50 : 0.99978 	oar :  1.0
#
#
# k in higher dimension: 500
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 1.0 	oar :  1.0
# 40 : 0.999925 	oar :  1.0
# 50 : 0.99986 	oar :  1.0
#
#
# k in higher dimension: 750
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 1.0 	oar :  1.0
# 40 : 1.0 	oar :  1.0
# 50 : 1.0 	oar :  1.0
#
#
# k in higher dimension: 1000
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 1.0 	oar :  1.0
# 40 : 1.0 	oar :  1.0
# 50 : 1.0 	oar :  1.0
#
#
# k in higher dimension: 2000
# 2 : 1.0 	oar :  1.0
# 3 : 1.0 	oar :  1.0
# 4 : 1.0 	oar :  1.0
# 5 : 1.0 	oar :  1.0
# 10 : 1.0 	oar :  1.0
# 20 : 1.0 	oar :  1.0
# 30 : 1.0 	oar :  1.0
# 40 : 1.0 	oar :  1.0
# 50 : 1.0 	oar :  1.0

# %%
with open('../tSNE_transform/random_2d_scikit_1M.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)

# %%
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 1000
# 1000
# 998
# 998
# 995
# 993
# 988
# 978
# 972
#
#
# k in higher dimension: 300
# 1000
# 1000
# 1000
# 1000
# 1000
# 998
# 990
# 984
# 979
#
#
# k in higher dimension: 400
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 998
# 996
# 993
#
#
# k in higher dimension: 500
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 999
# 997
# 996
#
#
# k in higher dimension: 750
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 2000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#
#
# k in higher dimension: 250
# 2 : 1.0
# 3 : 1.0
# 4 : 0.9995
# 5 : 0.9996
# 10 : 0.9991
# 20 : 0.9985
# 30 : 0.9979
# 40 : 0.997275
# 50 : 0.99674
#
#
# k in higher dimension: 300
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 0.99975
# 30 : 0.9991333333333333
# 40 : 0.99855
# 50 : 0.99816
#
#
# k in higher dimension: 400
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 1.0
# 30 : 0.9999333333333333
# 40 : 0.99975
# 50 : 0.99968
#
#
# k in higher dimension: 500
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 1.0
# 30 : 0.9999666666666667
# 40 : 0.9998
# 50 : 0.99978
#
#
# k in higher dimension: 750
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 1.0
# 30 : 1.0
# 40 : 1.0
# 50 : 1.0
#
#
# k in higher dimension: 1000
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 1.0
# 30 : 1.0
# 40 : 1.0
# 50 : 1.0
#
#
# k in higher dimension: 2000
# 2 : 1.0
# 3 : 1.0
# 4 : 1.0
# 5 : 1.0
# 10 : 1.0
# 20 : 1.0
# 30 : 1.0
# 40 : 1.0
# 50 : 1.0
