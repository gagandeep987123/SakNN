# %%
import tSNE_performance 
import numpy as np

# %%
with open('../tSNE_transform/transformationData/random_3d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)

# %%
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 988
# 952
# 927
# 900
# 791
# 601
# 469
# 362
# 270
#
#
# k in higher dimension: 300
# 988
# 952
# 929
# 904
# 802
# 626
# 502
# 405
# 325
#
#
# k in higher dimension: 400
# 988
# 953
# 932
# 908
# 813
# 650
# 548
# 468
# 392
#
#
# k in higher dimension: 500
# 989
# 955
# 933
# 909
# 814
# 666
# 571
# 494
# 427
#
#
# k in higher dimension: 750
# 989
# 957
# 935
# 913
# 825
# 686
# 600
# 530
# 471
#
#
# k in higher dimension: 1000
# 990
# 961
# 940
# 917
# 829
# 697
# 615
# 550
# 494
#
#
# k in higher dimension: 2000
# 992
# 968
# 950
# 930
# 851
# 724
# 650
# 595
# 544
#
#
# k in higher dimension: 250
# 2 : 0.994 	oar :  1.001652831916251
# 3 : 0.984 	oar :  1.0037990166281296
# 4 : 0.98 	oar :  1.0044957192507404
# 5 : 0.9756 	oar :  1.0052037796338604
# 10 : 0.9552 	oar :  1.0085576538612027
# 20 : 0.9235 	oar :  1.0147282784754412
# 30 : 0.8993666666666666 	oar :  1.0200721901896264
# 40 : 0.878 	oar :  1.0242676179699914
# 50 : 0.85776 	oar :  1.0280693621399155
#
#
# k in higher dimension: 300
# 2 : 0.994 	oar :  1.001652831916251
# 3 : 0.984 	oar :  1.0037990166281296
# 4 : 0.9805 	oar :  1.0044957192507404
# 5 : 0.9764 	oar :  1.0052037796338604
# 10 : 0.9573 	oar :  1.0085576538612027
# 20 : 0.9276 	oar :  1.0147282784754412
# 30 : 0.9054333333333333 	oar :  1.0200721901896264
# 40 : 0.885875 	oar :  1.0242676179699914
# 50 : 0.86804 	oar :  1.0280693621399155
#
#
# k in higher dimension: 400
# 2 : 0.994 	oar :  1.001652831916251
# 3 : 0.9843333333333333 	oar :  1.0037990166281296
# 4 : 0.98125 	oar :  1.0044957192507404
# 5 : 0.9772 	oar :  1.0052037796338604
# 10 : 0.9591 	oar :  1.0085576538612027
# 20 : 0.93205 	oar :  1.0147282784754412
# 30 : 0.9122 	oar :  1.0200721901896264
# 40 : 0.895625 	oar :  1.0242676179699914
# 50 : 0.88064 	oar :  1.0280693621399155
#
#
# k in higher dimension: 500
# 2 : 0.9945 	oar :  1.001652831916251
# 3 : 0.985 	oar :  1.0037990166281296
# 4 : 0.98175 	oar :  1.0044957192507404
# 5 : 0.9776 	oar :  1.0052037796338604
# 10 : 0.9597 	oar :  1.0085576538612027
# 20 : 0.934 	oar :  1.0147282784754412
# 30 : 0.9155 	oar :  1.0200721901896264
# 40 : 0.900075 	oar :  1.0242676179699914
# 50 : 0.88682 	oar :  1.0280693621399155
#
#
# k in higher dimension: 750
# 2 : 0.9945 	oar :  1.001652831916251
# 3 : 0.9856666666666667 	oar :  1.0037990166281296
# 4 : 0.98275 	oar :  1.0044957192507404
# 5 : 0.9788 	oar :  1.0052037796338604
# 10 : 0.9621 	oar :  1.0085576538612027
# 20 : 0.93815 	oar :  1.0147282784754412
# 30 : 0.9207333333333333 	oar :  1.0200721901896264
# 40 : 0.906725 	oar :  1.0242676179699914
# 50 : 0.89496 	oar :  1.0280693621399155
#
#
# k in higher dimension: 1000
# 2 : 0.995 	oar :  1.001652831916251
# 3 : 0.987 	oar :  1.0037990166281296
# 4 : 0.984 	oar :  1.0044957192507404
# 5 : 0.98 	oar :  1.0052037796338604
# 10 : 0.9639 	oar :  1.0085576538612027
# 20 : 0.94065 	oar :  1.0147282784754412
# 30 : 0.9244 	oar :  1.0200721901896264
# 40 : 0.91125 	oar :  1.0242676179699914
# 50 : 0.90058 	oar :  1.0280693621399155
#
#
# k in higher dimension: 2000
# 2 : 0.996 	oar :  1.001652831916251
# 3 : 0.9893333333333333 	oar :  1.0037990166281296
# 4 : 0.98675 	oar :  1.0044957192507404
# 5 : 0.9832 	oar :  1.0052037796338604
# 10 : 0.9689 	oar :  1.0085576538612027
# 20 : 0.9471 	oar :  1.0147282784754412
# 30 : 0.9323666666666667 	oar :  1.0200721901896264
# 40 : 0.920375 	oar :  1.0242676179699914
# 50 : 0.91108 	oar :  1.0280693621399155

# %%
with open('../tSNE_transform/random_3d.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)

# %%
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 987
# 968
# 937
# 912
# 784
# 591
# 438
# 311
# 238
#
#
# k in higher dimension: 300
# 987
# 968
# 937
# 913
# 791
# 617
# 481
# 383
# 301
#
#
# k in higher dimension: 400
# 988
# 969
# 938
# 915
# 799
# 640
# 521
# 448
# 380
#
#
# k in higher dimension: 500
# 988
# 969
# 939
# 917
# 802
# 658
# 549
# 473
# 418
#
#
# k in higher dimension: 750
# 988
# 970
# 942
# 920
# 811
# 673
# 579
# 508
# 462
#
#
# k in higher dimension: 1000
# 988
# 970
# 943
# 922
# 817
# 685
# 592
# 527
# 482
#
#
# k in higher dimension: 2000
# 988
# 971
# 945
# 926
# 830
# 709
# 621
# 562
# 523
#
#
# k in higher dimension: 250
# 2 : 0.9935
# 3 : 0.9876666666666667
# 4 : 0.98075
# 5 : 0.9752
# 10 : 0.9532
# 20 : 0.92095
# 30 : 0.8929333333333334
# 40 : 0.86825
# 50 : 0.84812
#
#
# k in higher dimension: 300
# 2 : 0.9935
# 3 : 0.9876666666666667
# 4 : 0.98075
# 5 : 0.9756
# 10 : 0.9545
# 20 : 0.9246
# 30 : 0.8991666666666667
# 40 : 0.878025
# 50 : 0.86076
#
#
# k in higher dimension: 400
# 2 : 0.994
# 3 : 0.988
# 4 : 0.981
# 5 : 0.976
# 10 : 0.9558
# 20 : 0.9291
# 30 : 0.9057
# 40 : 0.8876
# 50 : 0.8736
#
#
# k in higher dimension: 500
# 2 : 0.994
# 3 : 0.988
# 4 : 0.98125
# 5 : 0.9764
# 10 : 0.9568
# 20 : 0.9318
# 30 : 0.9104333333333333
# 40 : 0.89345
# 50 : 0.88062
#
#
# k in higher dimension: 750
# 2 : 0.994
# 3 : 0.9883333333333333
# 4 : 0.982
# 5 : 0.977
# 10 : 0.9585
# 20 : 0.9348
# 30 : 0.9155
# 40 : 0.9004
# 50 : 0.88948
#
#
# k in higher dimension: 1000
# 2 : 0.994
# 3 : 0.9883333333333333
# 4 : 0.98225
# 5 : 0.9774
# 10 : 0.96
# 20 : 0.9376
# 30 : 0.9189
# 40 : 0.9043
# 50 : 0.89394
#
#
# k in higher dimension: 2000
# 2 : 0.994
# 3 : 0.9886666666666667
# 4 : 0.983
# 5 : 0.9788
# 10 : 0.9632
# 20 : 0.9426
# 30 : 0.9253666666666667
# 40 : 0.912525
# 50 : 0.90354
