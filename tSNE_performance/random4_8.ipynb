# %%
import tSNE_performance 
import numpy as np

# %%
with open('../tSNE_transform/transformationData/random_4d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 963
# 900
# 820
# 760
# 499
# 259
# 137
# 72
# 31
#
#
# k in higher dimension: 300
# 965
# 903
# 825
# 767
# 515
# 281
# 161
# 86
# 47
#
#
# k in higher dimension: 400
# 966
# 905
# 835
# 774
# 533
# 314
# 189
# 120
# 79
#
#
# k in higher dimension: 500
# 966
# 907
# 838
# 777
# 550
# 339
# 210
# 137
# 97
#
#
# k in higher dimension: 750
# 967
# 911
# 843
# 788
# 572
# 372
# 246
# 174
# 130
#
#
# k in higher dimension: 1000
# 967
# 911
# 846
# 790
# 585
# 398
# 272
# 206
# 160
#
#
# k in higher dimension: 2000
# 971
# 917
# 858
# 805
# 613
# 450
# 329
# 259
# 211
#
#
# k in higher dimension: 250
# 2 : 0.9815 	oar :  1.0
# 3 : 0.9643333333333334 	oar :  1.0
# 4 : 0.94525 	oar :  1.0
# 5 : 0.9314 	oar :  1.0
# 10 : 0.878 	oar :  1.019800331486873
# 20 : 0.8128 	oar :  1.049765133653491
# 30 : 0.7681666666666667 	oar :  1.0781190850527271
# 40 : 0.73115 	oar :  1.0827556467341668
# 50 : 0.70078 	oar :  1.0955831756476389
#
#
# ...

# %%
with open('../tSNE_transform/transformationData/random_5d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 945
# 820
# 705
# 603
# 295
# 93
# 31
# 15
# 5
#
#
# k in higher dimension: 300
# 946
# 822
# 710
# 611
# 307
# 104
# 38
# 20
# 11
#
#
# k in higher dimension: 400
# 946
# 826
# 718
# 620
# 329
# 127
# 48
# 27
# 20
#
#
# k in higher dimension: 500
# 946
# 829
# 722
# 625
# 349
# 146
# 59
# 31
# 22
#
#
# k in higher dimension: 750
# 948
# 838
# 737
# 644
# 370
# 179
# 85
# 52
# 39
#
#
# k in higher dimension: 1000
# 952
# 848
# 750
# 659
# 386
# 195
# 97
# 62
# 46
#
#
# k in higher dimension: 2000
# 956
# 860
# 768
# 684
# 419
# 230
# 131
# 92
# 70
#
#
# k in higher dimension: 250
# 2 : 0.9725 	oar :  1.0
# 3 : 0.9363333333333334 	oar :  1.0
# 4 : 0.91 	oar :  1.0
# 5 : 0.885 	oar :  1.0
# 10 : 0.8055 	oar :  1.0360581168339271
# 20 : 0.7198 	oar :  1.049493535576369
# 30 : 0.6638333333333334 	oar :  1.0719019241966588
# 40 : 0.62255 	oar :  1.082693206949033
# 50 : 0.59134 	oar :  1.117887527061937
#
#
# k in higher dimension: 300
# ...

# %%
with open('../tSNE_transform/transformationData/random_6d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 895
# 726
# 570
# 455
# 182
# 42
# 9
# 0
# 0
#
#
# k in higher dimension: 300
# 895
# 730
# 581
# 470
# 197
# 50
# 11
# 2
# 2
#
#
# k in higher dimension: 400
# 899
# 738
# 590
# 480
# 207
# 64
# 21
# 7
# 2
#
#
# k in higher dimension: 500
# 900
# 745
# 599
# 491
# 215
# 71
# 24
# 10
# 4
#
#
# k in higher dimension: 750
# 902
# 751
# 610
# 507
# 239
# 88
# 35
# 16
# 6
#
#
# k in higher dimension: 1000
# 903
# 756
# 618
# 519
# 250
# 101
# 48
# 23
# 8
#
#
# k in higher dimension: 2000
# 910
# 772
# 643
# 547
# 292
# 132
# 67
# 36
# 18
#
#
# k in higher dimension: 250
# 2 : 0.9475 	oar :  1.1239994218832543
# 3 : 0.902 	oar :  1.0335291518699097
# 4 : 0.8635 	oar :  1.038680368595337
# 5 : 0.8326 	oar :  1.024983945604504
# 10 : 0.7382 	oar :  1.0769756792816474
# 20 : 0.6376 	oar :  1.0976135070100592
# 30 : 0.5803666666666667 	oar :  1.1043218761679243
# 40 : 0.539125 	oar :  1.1261353263274276
# ...

# %%
with open('../tSNE_transform/transformationData/random_7d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 889
# 665
# 477
# 362
# 99
# 9
# 1
# 0
# 0
#
#
# k in higher dimension: 300
# 889
# 671
# 488
# 375
# 107
# 11
# 1
# 0
# 0
#
#
# k in higher dimension: 400
# 890
# 674
# 496
# 389
# 119
# 17
# 3
# 2
# 2
#
#
# k in higher dimension: 500
# 890
# 677
# 504
# 399
# 132
# 26
# 8
# 4
# 3
#
#
# k in higher dimension: 750
# 894
# 688
# 517
# 411
# 145
# 32
# 14
# 7
# 3
#
#
# k in higher dimension: 1000
# 897
# 692
# 525
# 423
# 161
# 42
# 16
# 10
# 4
#
#
# k in higher dimension: 2000
# 902
# 710
# 554
# 461
# 191
# 65
# 25
# 14
# 9
#
#
# k in higher dimension: 250
# 2 : 0.9445 	oar :  1.0
# 3 : 0.879 	oar :  1.0
# 4 : 0.8285 	oar :  1.0276339823212979
# 5 : 0.793 	oar :  1.0548827637291989
# 10 : 0.6726 	oar :  1.0478981070308693
# 20 : 0.559 	oar :  1.108459760438816
# 30 : 0.5014 	oar :  1.119583805521758
# 40 : 0.4591 	oar :  1.1449205109057279
# 50 : 0.42916 	oar :  1.159929515433428
#
#
# k in higher dimension: 300
# ...

# %%
with open('../tSNE_transform/transformationData/random_8d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 885
# 639
# 445
# 315
# 62
# 2
# 1
# 1
# 0
#
#
# k in higher dimension: 300
# 886
# 643
# 454
# 327
# 66
# 5
# 1
# 1
# 0
#
#
# k in higher dimension: 400
# 889
# 651
# 462
# 338
# 76
# 6
# 1
# 1
# 0
#
#
# k in higher dimension: 500
# 890
# 655
# 471
# 347
# 88
# 11
# 2
# 2
# 1
#
#
# k in higher dimension: 750
# 890
# 663
# 487
# 361
# 98
# 13
# 4
# 3
# 1
#
#
# k in higher dimension: 1000
# 892
# 670
# 499
# 377
# 109
# 15
# 5
# 3
# 1
#
#
# k in higher dimension: 2000
# 899
# 691
# 532
# 414
# 149
# 30
# 12
# 6
# 2
#
#
# k in higher dimension: 250
# 2 : 0.9425 	oar :  1.0
# 3 : 0.8663333333333333 	oar :  1.0019771446999974
# 4 : 0.81125 	oar :  1.0163430057834777
# 5 : 0.7692 	oar :  1.0232908175104671
# 10 : 0.6348 	oar :  1.0580687177416992
# 20 : 0.511 	oar :  1.1242928533033163
# 30 : 0.44766666666666666 	oar :  1.1642113512535082
# 40 : 0.40725 	oar :  1.1961601459553484
# 50 : 0.37928 	oar :  1.207799822309463
#
#
# ...

# %%
with open('../tSNE_transform/random_7d_opentsne.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 54
# 5
# 2
# 1
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 300
# 67
# 9
# 3
# 2
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 400
# 76
# 13
# 5
# 3
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 500
# 96
# 18
# 5
# 3
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 750
# 139
# 24
# 7
# 5
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 1000
# 163
# 35
# 10
# 6
# 1
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 2000
# 248
# 86
# 38
# 19
# 3
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 250
# 2 : 0.527
# 3 : 0.36133333333333334
# 4 : 0.277
# 5 : 0.2282
# 10 : 0.121
# 20 : 0.0661
# 30 : 0.04713333333333333
# 40 : 0.037425
# 50 : 0.03104
#
#
# k in higher dimension: 300
# 2 : 0.5335
# 3 : 0.36766666666666664
# 4 : 0.28225
# 5 : 0.2326
# 10 : 0.1243
# 20 : 0.0687
# 30 : 0.0493
# 40 : 0.0395
# 50 : 0.03298
#
#
# k in higher dimension: 400
# 2 : 0.538
# 3 : 0.376
# 4 : 0.28975
# 5 : 0.2394
# 10 : 0.1311
# 20 : 0.0745
# ...

# %%
with open('../tSNE_transform/random_7d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 904
# 697
# 519
# 375
# 103
# 10
# 1
# 0
# 0
#
#
# k in higher dimension: 300
# 905
# 698
# 522
# 382
# 116
# 14
# 1
# 0
# 0
#
#
# k in higher dimension: 400
# 907
# 706
# 534
# 398
# 131
# 19
# 2
# 1
# 0
#
#
# k in higher dimension: 500
# 908
# 710
# 537
# 403
# 139
# 21
# 4
# 1
# 0
#
#
# k in higher dimension: 750
# 909
# 715
# 546
# 417
# 157
# 37
# 7
# 2
# 1
#
#
# k in higher dimension: 1000
# 911
# 719
# 554
# 426
# 167
# 43
# 11
# 4
# 2
#
#
# k in higher dimension: 2000
# 917
# 738
# 585
# 463
# 205
# 72
# 32
# 16
# 10
#
#
# k in higher dimension: 250
# 2 : 0.952
# 3 : 0.891
# 4 : 0.8415
# 5 : 0.8016
# 10 : 0.6856
# 20 : 0.57275
# 30 : 0.5091
# 40 : 0.46635
# 50 : 0.43448
#
#
# k in higher dimension: 300
# 2 : 0.9525
# 3 : 0.8916666666666667
# 4 : 0.84325
# 5 : 0.805
# 10 : 0.6933
# 20 : 0.5846
# 30 : 0.5233
# 40 : 0.482625
# 50 : 0.45146
#
#
# k in higher dimension: 400
# 2 : 0.9535
# 3 : 0.8946666666666667
# 4 : 0.84875
# ...

# %%
with open('../tSNE_transform/random_8d_opentsne.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 27
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 300
# 35
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 400
# 41
# 4
# 1
# 0
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 500
# 50
# 6
# 1
# 0
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 750
# 77
# 10
# 3
# 1
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 1000
# 100
# 17
# 5
# 1
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 2000
# 160
# 34
# 11
# 4
# 0
# 0
# 0
# 0
# 0
#
#
# k in higher dimension: 250
# 2 : 0.5135
# 3 : 0.34833333333333333
# 4 : 0.26525
# 5 : 0.2146
# 10 : 0.111
# 20 : 0.0579
# 30 : 0.040633333333333334
# 40 : 0.031675
# 50 : 0.02596
#
#
# k in higher dimension: 300
# 2 : 0.5175
# 3 : 0.3526666666666667
# 4 : 0.2695
# 5 : 0.2184
# 10 : 0.114
# 20 : 0.06
# 30 : 0.04276666666666667
# 40 : 0.03335
# 50 : 0.0274
#
#
# k in higher dimension: 400
# 2 : 0.5205
# 3 : 0.35733333333333334
# 4 : 0.27375
# 5 : 0.2236
# 10 : 0.1185
# ...

# %%
with open('../tSNE_transform/random_8d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 865
# 590
# 411
# 287
# 57
# 6
# 1
# 0
# 0
#
#
# k in higher dimension: 300
# 867
# 600
# 422
# 296
# 65
# 6
# 1
# 0
# 0
#
#
# k in higher dimension: 400
# 869
# 614
# 437
# 309
# 75
# 8
# 2
# 0
# 0
#
#
# k in higher dimension: 500
# 870
# 620
# 446
# 314
# 81
# 9
# 2
# 1
# 0
#
#
# k in higher dimension: 750
# 872
# 625
# 459
# 328
# 93
# 12
# 6
# 1
# 1
#
#
# k in higher dimension: 1000
# 877
# 636
# 474
# 346
# 104
# 18
# 8
# 2
# 2
#
#
# k in higher dimension: 2000
# 884
# 654
# 500
# 376
# 134
# 32
# 10
# 6
# 2
#
#
# k in higher dimension: 250
# 2 : 0.9325
# 3 : 0.8516666666666667
# 4 : 0.804
# 5 : 0.7606
# 10 : 0.6313
# 20 : 0.50615
# 30 : 0.4431333333333333
# 40 : 0.400625
# 50 : 0.36904
#
#
# k in higher dimension: 300
# 2 : 0.9335
# 3 : 0.8553333333333333
# 4 : 0.808
# 5 : 0.7656
# 10 : 0.6409
# 20 : 0.51915
# 30 : 0.4580666666666667
# 40 : 0.415675
# 50 : 0.3849
#
#
# k in higher dimension: 400
# 2 : 0.9345
# ...

# %%
with open('../tSNE_transform/random_9d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 867
# 585
# 374
# 242
# 35
# 4
# 0
# 0
# 0
#
#
# k in higher dimension: 300
# 869
# 590
# 382
# 253
# 41
# 4
# 0
# 0
# 0
#
#
# k in higher dimension: 400
# 874
# 598
# 399
# 272
# 48
# 5
# 0
# 0
# 0
#
#
# k in higher dimension: 500
# 876
# 608
# 414
# 289
# 55
# 5
# 0
# 0
# 0
#
#
# k in higher dimension: 750
# 877
# 613
# 421
# 299
# 65
# 8
# 1
# 0
# 0
#
#
# k in higher dimension: 1000
# 880
# 620
# 431
# 312
# 72
# 9
# 2
# 1
# 1
#
#
# k in higher dimension: 2000
# 887
# 628
# 447
# 330
# 95
# 20
# 4
# 2
# 1
#
#
# k in higher dimension: 250
# 2 : 0.9335
# 3 : 0.848
# 4 : 0.78475
# 5 : 0.7334
# 10 : 0.5849
# 20 : 0.46105
# 30 : 0.39743333333333336
# 40 : 0.357225
# 50 : 0.3297
#
#
# k in higher dimension: 300
# 2 : 0.9345
# 3 : 0.8496666666666667
# 4 : 0.7875
# 5 : 0.7382
# 10 : 0.5934
# 20 : 0.4724
# 30 : 0.4104
# 40 : 0.37085
# 50 : 0.34382
#
#
# k in higher dimension: 400
# 2 : 0.937
# 3 : 0.853
# 4 : 0.793
# 5 : 0.7452
# ...

# %%
with open('../tSNE_transform/random_10d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 848
# 561
# 321
# 196
# 22
# 1
# 0
# 0
# 0
#
#
# k in higher dimension: 300
# 848
# 565
# 328
# 203
# 26
# 1
# 0
# 0
# 0
#
#
# k in higher dimension: 400
# 854
# 577
# 344
# 217
# 34
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 500
# 858
# 583
# 350
# 224
# 40
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 750
# 859
# 592
# 364
# 242
# 48
# 4
# 1
# 0
# 0
#
#
# k in higher dimension: 1000
# 861
# 603
# 375
# 254
# 54
# 7
# 2
# 0
# 0
#
#
# k in higher dimension: 2000
# 868
# 627
# 404
# 284
# 73
# 13
# 4
# 0
# 0
#
#
# k in higher dimension: 250
# 2 : 0.924
# 3 : 0.8353333333333334
# 4 : 0.7605
# 5 : 0.7104
# 10 : 0.5595
# 20 : 0.42945
# 30 : 0.3691333333333333
# 40 : 0.3287
# 50 : 0.30104
#
#
# k in higher dimension: 300
# 2 : 0.924
# 3 : 0.8366666666666667
# 4 : 0.764
# 5 : 0.7142
# 10 : 0.5659
# 20 : 0.44015
# 30 : 0.3812
# 40 : 0.34185
# 50 : 0.31442
#
#
# k in higher dimension: 400
# 2 : 0.927
# 3 : 0.8406666666666667
# 4 : 0.77
# ...

# %%
with open('../tSNE_transform/random_11d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# All tasks completed
# k in higher dimension: 250
# 839
# 516
# 288
# 150
# 9
# 2
# 0
# 0
# 0
#
#
# k in higher dimension: 300
# 840
# 520
# 292
# 155
# 11
# 2
# 1
# 0
# 0
#
#
# k in higher dimension: 400
# 842
# 525
# 299
# 164
# 13
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 500
# 843
# 533
# 311
# 172
# 18
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 750
# 846
# 537
# 323
# 184
# 22
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 1000
# 846
# 541
# 327
# 190
# 24
# 3
# 1
# 0
# 0
#
#
# k in higher dimension: 2000
# 848
# 550
# 340
# 205
# 37
# 4
# 1
# 0
# 0
#
#
# k in higher dimension: 250
# 2 : 0.9195
# 3 : 0.8226666666666667
# 4 : 0.747
# 5 : 0.6844
# 10 : 0.5238
# 20 : 0.39075
# 30 : 0.32816666666666666
# 40 : 0.2907
# 50 : 0.26548
#
#
# k in higher dimension: 300
# 2 : 0.92
# 3 : 0.8243333333333334
# 4 : 0.749
# 5 : 0.6878
# 10 : 0.5308
# 20 : 0.3991
# 30 : 0.338
# 40 : 0.30115
# 50 : 0.27614
#
#
# k in higher dimension: 400
# 2 : 0.921
# 3 : 0.8263333333333334
# 4 : 0.7525
# ...

# %%
with open('../tSNE_transform/random_12d_scikit.npy', 'rb') as f:
    embedding4 = np.load(f)
    df = np.load(f)
tSNE_performance.performance_test(df,embedding4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 with open('../tSNE_transform/random_12d_scikit.npy', 'rb') as f:
#       2     embedding4 = np.load(f)
#       3     df = np.load(f)
#
# File ~/Testing/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../tSNE_transform/random_12d_scikit.npy'
