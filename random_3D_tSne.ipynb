# %%
import numpy as np
from sklearn.manifold import TSNE
import time

# %%
df = np.random.rand(3000000,3)

# %%
tsne = TSNE(n_components=2, random_state=42, n_jobs=25, verbose=10,n_iter=1500, perplexity=50)
start = time.time()
X_tsne = tsne.fit_transform(df)
end = time.time()
print("Time taken by scikit learn:",(end-start))
with open("transformationData/random_3d_"+"scikit"+".npy", 'wb') as f:
    np.save(f,X_tsne)
    np.save(f,df)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 3000000 samples in 1.919s...
# [t-SNE] Computed neighbors for 3000000 samples in 101.959s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 2000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 3000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 4000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 5000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 6000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 7000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 8000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 9000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 10000 / 3000000
# [t-SNE] Computed conditional probabilities for sample 11000 / 3000000
# ...

# %%
    np.save(f,embedding)
    np.save(f,df)

# %%
import numpy as np
df = np.random.rand(3724033,3)

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, random_state=42, n_jobs=25, verbose=10,n_iter=1500)

# %%
X_tsne = tsne.fit_transform(df)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3724033 samples in 2.649s...
# [t-SNE] Computed neighbors for 3724033 samples in 91.937s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 2000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 3000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 4000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 5000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 6000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 7000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 8000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 9000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 10000 / 3724033
# [t-SNE] Computed conditional probabilities for sample 11000 / 3724033
# ...

# %%
with open('transformationData/random_3d_scikit.npy', 'wb') as f:
    np.save(f,X_tsne)
    np.save(f,df)
